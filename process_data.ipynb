# %% [markdown]
# # Process data

# %%
import pandas as pd
from fuzzywuzzy import fuzz

# %%
train_df = pd.read_csv("train.csv")
train_df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            1                                 aye, jati sampurna
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# ...        ...                                                ...
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299997  299997                     tanjung gusta jl. yaya 2 no 17
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999          jaya maspion permata blok beryl b2  no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                               /
# 2                                          /siung
# 3                                      toko dita/
# 4                                  /jl. orde baru
# ...                                           ...
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299997                                          /
# 299998                                taman asri/
# 299999                      jaya maspion permata/
#
# [300000 rows x 3 columns]

# %% [markdown]
# Only take 10,000 samples for testing in notebook

# %%
train_df = train_df.sample(10000)
train_df
# Out:
#             id                                        raw_address  \
# 220978  220978                        jati kampung baru senapelan
# 93521    93521       jend soedi purwokerto wetan purwokerto timur
# 85325    85325                      tpa qurr ayun kh abdul wahid,
# 295540  295540  lubang buaya jl. monumen panca sak gang sadar ...
# 5451      5451                   warna warni jaya jogo banyuwangi
# ...        ...                                                ...
# 152846  152846  taman bunga sukamukti blok h1 no.18 depan lapa...
# 78724    78724  dataran tinggi soeka hatta 134 20351 binjai timur
# 234289  234289            kiar simp babakan surabaya kiaracondong
# 287198  287198    cuci motor sadi, rinj sidanegara cilacap tengah
# 299732  299732                            raya ranca, seng do pt,
#
#                                  POI/street
# 220978                                /jati
# 93521                           /jend soedi
# 85325                       /kh abdul wahid
# 295540  /jl. monumen panca sak gang sadar 9
# 5451                  warna warni jaya/jogo
# ...                                     ...
# 152846                         taman bunga/
# 78724                          /soeka hatta
# 234289                           /kiar simp
# 287198             cuci motor sadirman/rinj
# 299732                                    /
#
# [10000 rows x 3 columns]

# %% [markdown]
# Split POI and street into separate columns

# %%
train_df[["POI", "street"]] = train_df["POI/street"].str.split("/").to_list()
train_df
# Out:
#             id                                        raw_address  \
# 220978  220978                        jati kampung baru senapelan
# 93521    93521       jend soedi purwokerto wetan purwokerto timur
# 85325    85325                      tpa qurr ayun kh abdul wahid,
# 295540  295540  lubang buaya jl. monumen panca sak gang sadar ...
# 5451      5451                   warna warni jaya jogo banyuwangi
# ...        ...                                                ...
# 152846  152846  taman bunga sukamukti blok h1 no.18 depan lapa...
# 78724    78724  dataran tinggi soeka hatta 134 20351 binjai timur
# 234289  234289            kiar simp babakan surabaya kiaracondong
# 287198  287198    cuci motor sadi, rinj sidanegara cilacap tengah
# 299732  299732                            raya ranca, seng do pt,
#
#                                  POI/street                  POI  \
# 220978                                /jati
# 93521                           /jend soedi
# 85325                       /kh abdul wahid
# 295540  /jl. monumen panca sak gang sadar 9
# 5451                  warna warni jaya/jogo     warna warni jaya
# ...                                     ...                  ...
# 152846                         taman bunga/          taman bunga
# 78724                          /soeka hatta
# 234289                           /kiar simp
# 287198             cuci motor sadirman/rinj  cuci motor sadirman
# 299732                                    /
#
#                                     street
# 220978                                jati
# 93521                           jend soedi
# 85325                       kh abdul wahid
# 295540  jl. monumen panca sak gang sadar 9
# 5451                                  jogo
# ...                                    ...
# 152846
# 78724                          soeka hatta
# 234289                           kiar simp
# 287198                                rinj
# 299732
#
# [10000 rows x 5 columns]

# %% [markdown]
# Use Moses tokenizer to tokenize raw address, POI and street

# %%
from sacremoses import MosesTokenizer

mt = MosesTokenizer()

# %%
train_df["tokens"] = train_df["raw_address"].apply(mt.tokenize)
train_df["POI_tokens"] = train_df["POI"].apply(mt.tokenize)
train_df["street_tokens"] = train_df["street"].apply(mt.tokenize)
train_df
# Out:
#             id                                        raw_address  \
# 220978  220978                        jati kampung baru senapelan
# 93521    93521       jend soedi purwokerto wetan purwokerto timur
# 85325    85325                      tpa qurr ayun kh abdul wahid,
# 295540  295540  lubang buaya jl. monumen panca sak gang sadar ...
# 5451      5451                   warna warni jaya jogo banyuwangi
# ...        ...                                                ...
# 152846  152846  taman bunga sukamukti blok h1 no.18 depan lapa...
# 78724    78724  dataran tinggi soeka hatta 134 20351 binjai timur
# 234289  234289            kiar simp babakan surabaya kiaracondong
# 287198  287198    cuci motor sadi, rinj sidanegara cilacap tengah
# 299732  299732                            raya ranca, seng do pt,
#
#                                  POI/street                  POI  \
# 220978                                /jati
# 93521                           /jend soedi
# 85325                       /kh abdul wahid
# 295540  /jl. monumen panca sak gang sadar 9
# 5451                  warna warni jaya/jogo     warna warni jaya
# ...                                     ...                  ...
# 152846                         taman bunga/          taman bunga
# 78724                          /soeka hatta
# 234289                           /kiar simp
# 287198             cuci motor sadirman/rinj  cuci motor sadirman
# 299732                                    /
#
#                                     street  \
# 220978                                jati
# 93521                           jend soedi
# 85325                       kh abdul wahid
# 295540  jl. monumen panca sak gang sadar 9
# 5451                                  jogo
# ...                                    ...
# 152846
# 78724                          soeka hatta
# 234289                           kiar simp
# 287198                                rinj
# 299732
#
#                                                    tokens  \
# 220978                   [jati, kampung, baru, senapelan]
# 93521   [jend, soedi, purwokerto, wetan, purwokerto, t...
# 85325              [tpa, qurr, ayun, kh, abdul, wahid, ,]
# 295540  [lubang, buaya, jl., monumen, panca, sak, gang...
# 5451               [warna, warni, jaya, jogo, banyuwangi]
# ...                                                   ...
# 152846  [taman, bunga, sukamukti, blok, h1, no.18, dep...
# 78724   [dataran, tinggi, soeka, hatta, 134, 20351, bi...
# 234289      [kiar, simp, babakan, surabaya, kiaracondong]
# 287198  [cuci, motor, sadi, ,, rinj, sidanegara, cilac...
# 299732                  [raya, ranca, ,, seng, do, pt, ,]
#
#                      POI_tokens                               street_tokens
# 220978                       []                                      [jati]
# 93521                        []                               [jend, soedi]
# 85325                        []                          [kh, abdul, wahid]
# 295540                       []  [jl., monumen, panca, sak, gang, sadar, 9]
# 5451       [warna, warni, jaya]                                      [jogo]
# ...                         ...                                         ...
# 152846           [taman, bunga]                                          []
# 78724                        []                              [soeka, hatta]
# 234289                       []                                [kiar, simp]
# 287198  [cuci, motor, sadirman]                                      [rinj]
# 299732                       []                                          []
#
# [10000 rows x 8 columns]

# %% [markdown]
# Labelling the tokens by matching POI and street with the raw address
# - Use fuzzy match because not all POI and street are complete in the raw address

# %%
def label_tokens(row, entity_types=["POI", "street"]):
    len_tokens = {x: len(row[f"{x}_tokens"]) for x in entity_types}
    all_tokens = len(row["tokens"])
    label = ["O"] * all_tokens
    
    for x in entity_types:
        max_score = 0
        max_i = 0
        
        if len_tokens[x] == 0:
            continue
            
        for i in range(all_tokens - len_tokens[x]):
            score = fuzz.ratio(row["tokens"][i:i+len_tokens[x]], row[f"{x}_tokens"])
            
            if score == 100:
                max_i = i
                break
            if score > max_score:
                max_score = score
                
        label[max_i:max_i+len_tokens[x]] = [x] * len_tokens[x]
        
    return label

train_df["label"] = train_df.apply(label_tokens, axis=1)
train_df
# Out:
#             id                                        raw_address  \
# 220978  220978                        jati kampung baru senapelan
# 93521    93521       jend soedi purwokerto wetan purwokerto timur
# 85325    85325                      tpa qurr ayun kh abdul wahid,
# 295540  295540  lubang buaya jl. monumen panca sak gang sadar ...
# 5451      5451                   warna warni jaya jogo banyuwangi
# ...        ...                                                ...
# 152846  152846  taman bunga sukamukti blok h1 no.18 depan lapa...
# 78724    78724  dataran tinggi soeka hatta 134 20351 binjai timur
# 234289  234289            kiar simp babakan surabaya kiaracondong
# 287198  287198    cuci motor sadi, rinj sidanegara cilacap tengah
# 299732  299732                            raya ranca, seng do pt,
#
#                                  POI/street                  POI  \
# 220978                                /jati
# 93521                           /jend soedi
# 85325                       /kh abdul wahid
# 295540  /jl. monumen panca sak gang sadar 9
# 5451                  warna warni jaya/jogo     warna warni jaya
# ...                                     ...                  ...
# 152846                         taman bunga/          taman bunga
# 78724                          /soeka hatta
# 234289                           /kiar simp
# 287198             cuci motor sadirman/rinj  cuci motor sadirman
# 299732                                    /
#
#                                     street  \
# 220978                                jati
# 93521                           jend soedi
# 85325                       kh abdul wahid
# 295540  jl. monumen panca sak gang sadar 9
# 5451                                  jogo
# ...                                    ...
# 152846
# 78724                          soeka hatta
# 234289                           kiar simp
# 287198                                rinj
# 299732
#
#                                                    tokens  \
# 220978                   [jati, kampung, baru, senapelan]
# 93521   [jend, soedi, purwokerto, wetan, purwokerto, t...
# 85325              [tpa, qurr, ayun, kh, abdul, wahid, ,]
# 295540  [lubang, buaya, jl., monumen, panca, sak, gang...
# 5451               [warna, warni, jaya, jogo, banyuwangi]
# ...                                                   ...
# 152846  [taman, bunga, sukamukti, blok, h1, no.18, dep...
# 78724   [dataran, tinggi, soeka, hatta, 134, 20351, bi...
# 234289      [kiar, simp, babakan, surabaya, kiaracondong]
# 287198  [cuci, motor, sadi, ,, rinj, sidanegara, cilac...
# 299732                  [raya, ranca, ,, seng, do, pt, ,]
#
#                      POI_tokens                               street_tokens  \
# 220978                       []                                      [jati]
# 93521                        []                               [jend, soedi]
# 85325                        []                          [kh, abdul, wahid]
# 295540                       []  [jl., monumen, panca, sak, gang, sadar, 9]
# 5451       [warna, warni, jaya]                                      [jogo]
# ...                         ...                                         ...
# 152846           [taman, bunga]                                          []
# 78724                        []                              [soeka, hatta]
# 234289                       []                                [kiar, simp]
# 287198  [cuci, motor, sadirman]                                      [rinj]
# 299732                       []                                          []
#
#                                                     label
# 220978                                  [street, O, O, O]
# 93521                        [street, street, O, O, O, O]
# 85325                [O, O, O, street, street, street, O]
# 295540  [O, O, street, street, street, street, street,...
# 5451                           [POI, POI, POI, street, O]
# ...                                                   ...
# 152846                    [POI, POI, O, O, O, O, O, O, O]
# 78724                  [O, O, street, street, O, O, O, O]
# 234289                          [street, street, O, O, O]
# 287198                [POI, POI, POI, O, street, O, O, O]
# 299732                              [O, O, O, O, O, O, O]
#
# [10000 rows x 9 columns]
